# %% [markdown]
# # Week 0 - Search
#
# https://cs50.harvard.edu/ai/2023/weeks/0/

# %%
from google.colab import drive

drive.mount('/content/drive')

gdrive_path = 'Learning/harvard_cs50'
root_path = "/content/drive" + "/MyDrive" + gdrive_path
# %cd /content/drive/MyDrive/Learning/harvard_cs50
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Learning/harvard_cs50
# harvard_cs50  Search.ipynb

# %% [markdown]
# # GIT integration

# %%
# %cd /content/drive/MyDrive/Learning/harvard_cs50/
# Out:
# /content/drive/MyDrive/Learning/harvard_cs50

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Search.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .
# !git commit -m "Adding initial notebook file"
# Out:
# [main 140f819] Adding initial notebook file
#  1 file changed, 1 insertion(+)
#  create mode 100644 Search.ipynb

# %%
# !git push
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.74 KiB | 356.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/jgoriasilva/harvard_cs50.git
#    3757505..140f819  main -> main
